# %% [markdown]
# <a href="https://colab.research.google.com/github/MustafaShama98/Cloud-Compute/blob/main/Tirgul_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install firebase
# !pip install nltk
# Out:
# Collecting firebase
#   Downloading firebase-4.0.1-py3-none-any.whl (12 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from firebase) (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->firebase) (2024.2.2)
# Installing collected packages: firebase
# Successfully installed firebase-4.0.1
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.12.25)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.2)

# %%
import nltk
from nltk.chat.util import Chat, reflections

# Download necessary NLTK data
nltk.download('punkt')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import requests
# Define some patterns and responses
  ################################
##info for the indexes from the website for chatbot
from bs4 import BeautifulSoup
def extract_content_from_url(url):
    headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.3'
  }
    response = requests.get(url,headers=headers)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        h1_tags = soup.find_all('h1')
        for h1_tag in h1_tags:
            # Find the next sibling div tag
            div_tag = h1_tag.find_next_sibling('div')
            if div_tag:
                # Find the first p tag under the div tag
                p_tag = div_tag.find('p')
                if p_tag:
                    return(p_tag.text.strip())
                else:
                    return("No p tag found under", h1_tag.text.strip())
            else:
                return("No div tag found after", h1_tag.text.strip())


    else:
        print("Failed to fetch webpage")
        return None



##the pattern to chatbot

from firebase import firebase
firebase = firebase.FirebaseApplication('https://cloudcomputing-2bbc8-default-rtdb.europe-west1.firebasedatabase.app', None)
result = firebase.get('/vmware_indexes', None)
a=[]
l=[]

for key,Link in result.items():
    a.append(key)
    l.append(Link['Link'])

print(a)
patterns = [
   (r'how are you?', ['I\'m good, thank you!', 'I\'m doing well, thanks for asking.']),
    (r'(.*) your name?', ['You can call me Chatbot.', 'I go by the name Chatbot.']),
    (r'exit|bye', ['goodbye','bye','have a good day']),
    (r'what can you do\?', ['I can assist you with various tasks, such as answering questions, providing information, or just having a conversation.']),
    (r'help(.*)', ['Sure, what do you need help with?', 'How can I assist you?']),
    (r'thank you(.*)|(.*)thanks(.*)', ['You\'re welcome!', 'No problem!', 'Happy to help!']),
     (r'who created you\?', ['I was created by the developers muhammed fozi mustafa and tamer.']),
    (r'what is your purpose\?', ['My purpose is to assist and interact with users like you.']),


  ]
import re
for key, link in zip(a, l):
    pattern = r'(?i)(.*)link(.*){}(.*)|(.*){}(.*)link(.*)'.format(re.escape(key), re.escape(key))
    patterns.append((pattern, [link]))
for key, link in zip(a, l):
    patterns.append((r'(.*){}(.*)'.format(key, key), [extract_content_from_url(link)]))

# import re
# # Create patterns for each index in array 'a'
# for index in a:
#     # Create a pattern that matches the index regardless of case
#     pattern = r'(.*){}(.*)'.format(re.escape(index), re.IGNORECASE)
#     patterns.append((pattern, [index]))

#take the words from the website to add to the chat box pattern
# Out:
# ['Automate the Network', 'Azure Spring Apps', 'Build a Multi-Cloud Network', 'Carbon Black App Control', 'Carbon Black Cloud', 'Carbon Black Endpoint', 'Carbon Black Workload', 'Cloud Director', 'Cloud Provider Platform', 'Cloud and Edge Infrastructure', 'Dynamic Environment Manager', 'Edge Network Intelligence (ENI)', 'Embrace Anywhere Workspace', 'Enable Modern Management', 'Enable the Multi-Cloud Edge', 'HCX', 'Horizon Cloud', 'Horizon Cloud on Microsoft Azure', 'IBM Cloud for VMware Solutions', 'Mobile Threat Defense', 'NSX Advanced Load Balancer', 'NSX Cloud', 'NSX Distributed Firewall', 'Network Modernization', 'Network Security', 'Oracle Cloud VMware Solution', 'Realize DevSecOps Outcomes', 'Secure Cloud Workloads', 'Secure Remote Access', 'Secure Your Network', 'Store, Process, and Query Critical Data', 'Strengthen App & Network Access', 'Success 360', 'Tanzu Application Platform', 'Tanzu Greenplum', 'Tanzu Guardrails', 'Tanzu Insights', 'Tanzu Mission Control', 'Tanzu Postgres', 'Tanzu Service Mesh', 'Telco Cloud Service Assurance', 'Transform Telco Cloud', 'VMWare Integrated OpenStack', 'VMware Aria Automation', 'VMware Aria Automation Orchestrator', 'VMware Aria Operations', 'VMware Aria Operations Management Pack for Horizon', 'VMware Aria Suite Lifecycle', 'VMware Cloud', 'VMware Cloud Director service', 'VMware Cloud on AWS', 'VMware Cloud on AWS Outposts', 'VMware Ransomware Recovery', 'VMware SaaS App Management by BetterCloud', 'VMware Secure Access (SA, ZTNA)', 'VMware Skyline', 'VMware Tanzu Hub', 'VMware vCenter Converter Standalone', 'VMware vSphere\u202fDistributed Services Engine', 'Workspace ONE Boxer', 'Workspace ONE Intelligent Hub', 'Workspace ONE Launcher', 'Workspace ONE UEM', 'vCenter Server', 'vSphere Hypervisor', 'vSphere with Tanzu']

# %%
 # Create a chatbot
chatbot = Chat(patterns, reflections)

  # Start the conversation
def chatbot_page():

    print("Hello "+ login_ui.username+"! I'm ChatGPT. How can I help you today?")
    while True:
        user_input = input("You: ")
        response = chatbot.respond(user_input)
        print("ChatGPT:", response)
        if user_input.lower() == 'exit' or user_input.lower() == 'bye':
            break


import ipywidgets as widgets
from IPython.display import display

class ChatUI:
    def __init__(self):
        self.label = widgets.Label(value="Hello! I'm ChatGPT. How can I help you today?")
        self.user_input = widgets.Text(placeholder='Type your message here...')
        self.conversation = widgets.Output()
        self.send_button = widgets.Button(description='Send')
        self.send_button.on_click(self.send_message)

        self.chatbot = Chatbot()
        # Display a note with a few indexes from the 'a' array
        note_text = "Choose to ask questions about: "
        indexes_to_display = a[:3]  # Display the first 3 indexes
        note_text += ", ".join(indexes_to_display)
        self.note_label = widgets.Label(value=note_text)

        display(widgets.VBox([self.note_label,self.label, self.conversation, self.user_input, self.send_button]))

    def send_message(self, _):
        user_input = self.user_input.value
        with self.conversation:
            print('You:', user_input)
            response = self.chatbot.respond(user_input)

        self.user_input.value = ''



class Chatbot:


      def respond(self, user_input):
          response = chatbot.respond(user_input)
          print("ChatGPT:", response)
          if user_input.lower() == 'exit' or user_input.lower() == 'bye':
              return
if __name__ == '__main__':
    chat_ui = ChatUI()
# Out:
# VBox(children=(Label(value='Choose to ask questions about: Automate the Network, Azure Spring Apps, Build a Mu…
